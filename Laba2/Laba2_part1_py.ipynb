# %%
q = 26781274432525236246246426232362812708871094021124912478464784930303983023802803570239750297350920529732507250751
p = 764164861678448570381035710359710355726605817359137053910517509501901951059170591750197501957107501753017510510571032423387
 
n = q*p
print("Открытый ключ n -", n)
 
#Создаем сообщение М<n
M = 12
print("Исходное сообщение:", M)
 
#Шифрование
#C = 984606242897781351877378204790413442900511119255246275585989233851641852963303435142231314451079610078358398311369424296085399803119509709622481188960362282243281
C = 21507232783116604478118897394211856345085885029960535067823593536310843852027320753560804685331127451923396642901592757697526179627697397334173215324888255947005993576951261211032134798473303949674871608041

print('зашифрованное сообщение:', C)
#Расшифровка
m1 = pow(C, (p+1)//4, p)
m2 = -pow(C, (p+1)//4, p)
m3 = pow(C, (q+1)//4, q)
m4 = -pow(C, (q+1)//4, q)
#print(m1, m2, m3 , m4)
 
#вычислим a и b
a = q * pow(q, p-2, p) 
b = p * pow(p, q-2, q)
#print("a=", a, "b=", b)
 
#получаем 4 текста  
M1 = (a * m1 + b * m3) % n
M2 = (a * m1 + b * m4) % n
M3 = (a * m2 + b * m3) % n
M4 = (a * m2 + b * m4) % n
print(M1)
print()
print(M2)
print()
print(M3)
print()
print(M4)
# Out:
# Открытый ключ n - 20465308872303218386833992021513940459142298963053787231845292696264623684674067432279415044880525281115532019672407508100263446152121831467310804271577440349156635097166161222971979497328785862997951922587079428490751295277892405713637
# Исходное сообщение: 12
# зашифрованное сообщение: 21507232783116604478118897394211856345085885029960535067823593536310843852027320753560804685331127451923396642901592757697526179627697397334173215324888255947005993576951261211032134798473303949674871608041
# 5135555117900767586543776122811195516708793071137716986138078612468136555265023676642180280653613433410343059788974308269892154850357616009920908566358313943289396691033893397898401338057819357964584481883686984404200599802968197594257
#
# 4637589113226462247720436660056613334327066379220567599961004854160973280066837551091083581053847172179
#
# 20465308872303218386833992021513940459142298963053787231845292696264623684674067432279415044880525281115532019672407508100263446152117193878197577809329719912496578483831834156592758929728824858143790949307012590939660211696838558541458
#
# 15329753754402450800290215898702744942433505891916070245707214083796487129409043755637234764226911847705188959883433199830371291301764215457389895705219126405867238406132267825073578159270966505033367440703392444086550695474924208119380
